# %% [markdown]
# # Data Characterization and Quality Assessment Notebook

# %% [markdown]
# ## Input Data

# %% [markdown]
# - Read data
# - Histograms and distributions
# - Scatter plots
# - Density plots
# - Key nummbers and summary statistics
# - Clean memory

# %% [markdown]
# ## Output Data

# %% [markdown]
# - Read data
# - Histograms and distributions
# - Key nummbers and summary statistics
# - PZ metrics
# - PZ validation plots
# - Clean memory
